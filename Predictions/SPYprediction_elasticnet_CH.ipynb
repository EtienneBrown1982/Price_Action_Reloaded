# %%
#imports
import numpy as np
import os
import pandas as pd

import math

from datetime import datetime, timedelta
from dotenv import load_dotenv
 
import yfinance as yf

import hvplot.pandas

from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import balanced_accuracy_score
from sklearn.linear_model import ElasticNet

# %%
load_dotenv()
# Out:
# True

# %%
source_df = None

# %%
symbol = 'AMZN'
file_name = f"{symbol}.csv"
source_df = None

# %%
if os.path.exists(file_name):
    source_df = pd.read_csv(file_name)

# %%
if source_df is None:
    display("download")
    ticker = yf.Ticker(symbol)
    start = datetime.utcnow() - timedelta(days=10*365)
    end=datetime.utcnow() - timedelta(days=1)
    source_df = ticker.history(start=start, end=end)
    source_df.to_csv(f"{symbol}.csv")

# %%
display(source_df.tail())
# Out:
#                            Date        Open        High         Low  \
# 2508  2024-02-16 00:00:00-05:00  168.740005  170.419998  167.169998
# 2509  2024-02-20 00:00:00-05:00  167.830002  168.710007  165.740005
# 2510  2024-02-21 00:00:00-05:00  168.940002  170.229996  167.139999
# 2511  2024-02-22 00:00:00-05:00  173.100006  174.800003  171.770004
# 2512  2024-02-23 00:00:00-05:00  174.279999  175.750000  173.699997
#
#            Close    Volume  Dividends  Stock Splits
# 2508  169.509995  48074600        0.0           0.0
# 2509  167.080002  41980300        0.0           0.0
# 2510  168.589996  44575600        0.0           0.0
# 2511  174.580002  55392400        0.0           0.0
# 2512  174.990005  59662900        0.0           0.0

# %%
bars_df = source_df.copy()
bars_df["Next Close"] = bars_df["Close"].shift(-1)
bars_df["Next High"] = bars_df["High"].shift(-1)
bars_df["Next Low"] = bars_df["Low"].shift(-1)

#15 and 60 minute window for high,low and open
period = 1
windows = [3, 12]

for window in windows:
    wp = window*period
    bars_df[f"High - {wp}"] = bars_df["High"].rolling(window=window).max()
    bars_df[f"Low - {wp}"] = bars_df["Low"].rolling(window=window).min()
    bars_df[f"Open - {wp}"] = bars_df["Open"].shift(periods=window-1)
    
bars_df = bars_df.dropna()
display(bars_df)
# Out:
#                            Date        Open        High         Low  \
# 11    2014-03-18 00:00:00-04:00   18.865999   18.950001   18.750000
# 12    2014-03-19 00:00:00-04:00   18.938499   18.950001   18.471001
# 13    2014-03-20 00:00:00-04:00   18.532000   18.650000   18.311001
# 14    2014-03-21 00:00:00-04:00   18.549999   18.642000   17.920000
# 15    2014-03-24 00:00:00-04:00   18.004499   18.075001   17.430000
# ...                         ...         ...         ...         ...
# 2507  2024-02-15 00:00:00-05:00  170.580002  171.169998  167.589996
# 2508  2024-02-16 00:00:00-05:00  168.740005  170.419998  167.169998
# 2509  2024-02-20 00:00:00-05:00  167.830002  168.710007  165.740005
# 2510  2024-02-21 00:00:00-05:00  168.940002  170.229996  167.139999
# 2511  2024-02-22 00:00:00-05:00  173.100006  174.800003  171.770004
#
#            Close     Volume  Dividends  Stock Splits  Next Close   Next High  \
# 11     18.938499   49670000        0.0           0.0   18.661501   18.950001
# 12     18.661501   52934000        0.0           0.0   18.448500   18.650000
# 13     18.448500   51170000        0.0           0.0   18.031000   18.642000
# 14     18.031000  108282000        0.0           0.0   17.592501   18.075001
# 15     17.592501   97470000        0.0           0.0   17.735500   17.948500
# ...          ...        ...        ...           ...         ...         ...
# 2507  169.800003   49855200        0.0           0.0  169.509995  170.419998
# 2508  169.509995   48074600        0.0           0.0  167.080002  168.710007
# 2509  167.080002   41980300        0.0           0.0  168.589996  170.229996
# 2510  168.589996   44575600        0.0           0.0  174.580002  174.800003
# 2511  174.580002   55392400        0.0           0.0  174.990005  175.750000
#
#         Next Low    High - 3     Low - 3    Open - 3   High - 12    Low - 12  \
# 11     18.471001   18.950001   18.577499   18.639999   19.155500   17.724001
# 12     18.311001   18.950001   18.471001   18.785999   19.155500   18.122999
# 13     17.920000   18.950001   18.311001   18.865999   19.155500   18.180500
# 14     17.430000   18.950001   17.920000   18.938499   19.155500   17.920000
# 15     17.441999   18.650000   17.430000   18.532000   19.155500   17.430000
# ...          ...         ...         ...         ...         ...         ...
# 2507  167.169998  171.210007  165.750000  167.729996  175.389999  154.809998
# 2508  165.740005  171.210007  167.169998  169.210007  175.389999  155.619995
# 2509  167.139999  171.169998  165.740005  170.580002  175.389999  165.740005
# 2510  171.770004  170.419998  165.740005  168.740005  175.389999  165.740005
# 2511  173.699997  174.800003  165.740005  167.830002  175.389999  165.740005
#
#        Open - 12
# 11     17.937000
# 12     18.195000
# 13     18.206499
# 14     18.702499
# 15     18.729000
# ...          ...
# 2507  157.000000
# 2508  155.869995
# 2509  169.190002
# 2510  170.199997
# 2511  169.389999
#
# [2501 rows x 17 columns]

# %%
df = bars_df.reset_index()
ys = {
    "Predicted High": df["Next High"], 
    "Predicted Low": df["Next Low"], 
    "Predicted Close": df["Next Close"],
}

X = df.drop(columns=["Next Close", "Next Low", "Next High", "Date"])
display(X)
# Out:
#       index        Open        High         Low       Close     Volume  \
# 0        11   18.865999   18.950001   18.750000   18.938499   49670000
# 1        12   18.938499   18.950001   18.471001   18.661501   52934000
# 2        13   18.532000   18.650000   18.311001   18.448500   51170000
# 3        14   18.549999   18.642000   17.920000   18.031000  108282000
# 4        15   18.004499   18.075001   17.430000   17.592501   97470000
# ...     ...         ...         ...         ...         ...        ...
# 2496   2507  170.580002  171.169998  167.589996  169.800003   49855200
# 2497   2508  168.740005  170.419998  167.169998  169.509995   48074600
# 2498   2509  167.830002  168.710007  165.740005  167.080002   41980300
# 2499   2510  168.940002  170.229996  167.139999  168.589996   44575600
# 2500   2511  173.100006  174.800003  171.770004  174.580002   55392400
#
#       Dividends  Stock Splits    High - 3     Low - 3    Open - 3   High - 12  \
# 0           0.0           0.0   18.950001   18.577499   18.639999   19.155500
# 1           0.0           0.0   18.950001   18.471001   18.785999   19.155500
# 2           0.0           0.0   18.950001   18.311001   18.865999   19.155500
# 3           0.0           0.0   18.950001   17.920000   18.938499   19.155500
# 4           0.0           0.0   18.650000   17.430000   18.532000   19.155500
# ...         ...           ...         ...         ...         ...         ...
# 2496        0.0           0.0  171.210007  165.750000  167.729996  175.389999
# 2497        0.0           0.0  171.210007  167.169998  169.210007  175.389999
# 2498        0.0           0.0  171.169998  165.740005  170.580002  175.389999
# 2499        0.0           0.0  170.419998  165.740005  168.740005  175.389999
# 2500        0.0           0.0  174.800003  165.740005  167.830002  175.389999
#
#         Low - 12   Open - 12
# 0      17.724001   17.937000
# 1      18.122999   18.195000
# 2      18.180500   18.206499
# 3      17.920000   18.702499
# 4      17.430000   18.729000
# ...          ...         ...
# 2496  154.809998  157.000000
# 2497  155.619995  155.869995
# 2498  165.740005  169.190002
# 2499  165.740005  170.199997
# 2500  165.740005  169.389999
#
# [2501 rows x 14 columns]

# %%
for name, y in ys.items():
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
    model = ElasticNet()
    model.fit(X_train, y_train)
    predicted_y_values = model.predict(X)
    # create copy of original data
    bars_df[name] = predicted_y_values
    bars_df
# Out:
# /Users/caraharmon/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.553e+03, tolerance: 5.136e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/caraharmon/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.066e+03, tolerance: 4.882e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/caraharmon/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.221e+03, tolerance: 5.009e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
display(bars_df.tail())
# Out:
#                            Date        Open        High         Low  \
# 2507  2024-02-15 00:00:00-05:00  170.580002  171.169998  167.589996
# 2508  2024-02-16 00:00:00-05:00  168.740005  170.419998  167.169998
# 2509  2024-02-20 00:00:00-05:00  167.830002  168.710007  165.740005
# 2510  2024-02-21 00:00:00-05:00  168.940002  170.229996  167.139999
# 2511  2024-02-22 00:00:00-05:00  173.100006  174.800003  171.770004
#
#            Close    Volume  Dividends  Stock Splits  Next Close   Next High  \
# 2507  169.800003  49855200        0.0           0.0  169.509995  170.419998
# 2508  169.509995  48074600        0.0           0.0  167.080002  168.710007
# 2509  167.080002  41980300        0.0           0.0  168.589996  170.229996
# 2510  168.589996  44575600        0.0           0.0  174.580002  174.800003
# 2511  174.580002  55392400        0.0           0.0  174.990005  175.750000
#
#         Next Low    High - 3     Low - 3    Open - 3   High - 12    Low - 12  \
# 2507  167.169998  171.210007  165.750000  167.729996  175.389999  154.809998
# 2508  165.740005  171.210007  167.169998  169.210007  175.389999  155.619995
# 2509  167.139999  171.169998  165.740005  170.580002  175.389999  165.740005
# 2510  171.770004  170.419998  165.740005  168.740005  175.389999  165.740005
# 2511  173.699997  174.800003  165.740005  167.830002  175.389999  165.740005
#
#        Open - 12  Predicted High  Predicted Low  Predicted Close
# 2507  157.000000      171.791441     168.015597       169.857266
# 2508  155.869995      170.771779     167.091065       169.024534
# 2509  169.190002      169.020139     165.201500       167.241072
# 2510  170.199997      170.548265     166.881521       168.760008
# 2511  169.389999      175.852239     171.895185       173.640420

# %%
bars_df["High/Low Success"] = np.where(
    (bars_df["Next Close"] >= bars_df["Predicted Low"]),
    np.where(
        bars_df["Next Close"] <= bars_df["Predicted High"], 1, 0
    ), 0
)

# %%
bars_df["Predicted Close Delta"] = bars_df["Predicted Close"] - bars_df["Close"]
bars_df["Next Close Delta"] = bars_df["Next Close"] - bars_df["Close"]
bars_df["Close Product"] = bars_df["Next Close Delta"] * bars_df["Predicted Close Delta"]
bars_df["Close Success"] = np.where(
    bars_df["Close Product"] >= 0, 1, 0
)

# %%
actual_close = bars_df.hvplot.line(
    x="Date",
    y="Next Close",
)

# %%
predicted_high = bars_df.hvplot.line(
    x="Date",
    y="Predicted High",
)

# %%
predicted_low = bars_df.hvplot.line(
    x="Date",
    y="Predicted Low",
)

# %%
predicted_close = bars_df.hvplot.line(
    x="Date",
    y="Predicted Close",
)

# %%
actual_close * predicted_high * predicted_low * predicted_close
# Out:
# :Overlay
#    .Curve.I   :Curve   [Date]   (Next Close)
#    .Curve.II  :Curve   [Date]   (Predicted High)
#    .Curve.III :Curve   [Date]   (Predicted Low)
#    .Curve.IV  :Curve   [Date]   (Predicted Close)

# %%
bars_df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2501.000000  2501.000000  2501.000000  2501.000000  2.501000e+03
# mean     86.860588    87.866244    85.767350    86.838953  7.982506e+07
# std      51.487107    52.118155    50.807534    51.457750  4.136324e+07
# min      14.220000    14.521000    14.200000    14.347500  1.762600e+07
# 25%      38.190498    38.387001    37.862499    38.050499  5.359400e+07
# 50%      88.339996    89.208000    87.283997    88.250000  6.840800e+07
# 75%     130.570007   132.050003   128.770004   130.149994  9.271000e+07
# max     187.199997   188.654007   184.839493   186.570496  4.771220e+08
#
#        Dividends  Stock Splits   Next Close    Next High     Next Low  ...  \
# count     2501.0   2501.000000  2501.000000  2501.000000  2501.000000  ...
# mean         0.0      0.007997    86.901348    87.928939    85.829305  ...
# std          0.0      0.399920    51.469993    52.129529    50.820252  ...
# min          0.0      0.000000    14.347500    14.521000    14.200000  ...
# 25%          0.0      0.000000    38.054501    38.404499    37.879002  ...
# 50%          0.0      0.000000    88.256500    89.293999    87.290001  ...
# 75%          0.0      0.000000   130.220001   132.070007   128.800003  ...
# max          0.0     20.000000   186.570496   188.654007   184.839493  ...
#
#           Low - 12    Open - 12  Predicted High  Predicted Low  \
# count  2501.000000  2501.000000     2501.000000    2501.000000
# mean     81.869991    86.193883       87.905722      85.802499
# std      48.643926    51.386203       52.069047      50.758150
# min      14.200000    14.220000       14.263755      12.376203
# 25%      36.834999    38.002499       38.543303      37.901636
# 50%      84.252998    88.000000       89.388200      87.147353
# 75%     123.660004   129.848999      131.910028     128.724672
# max     174.957993   187.199997      188.221410     184.660555
#
#        Predicted Close  High/Low Success  Predicted Close Delta  \
# count      2501.000000       2501.000000            2501.000000
# mean         86.882463          0.457817               0.043510
# std          51.397291          0.498317               0.803654
# min          13.434280          0.000000              -4.316161
# 25%          38.305076          0.000000              -0.289048
# 50%          88.280948          0.000000               0.083824
# 75%         130.367348          1.000000               0.299889
# max         186.203357          1.000000               4.917222
#
#        Next Close Delta  Close Product  Close Success
# count       2501.000000    2501.000000    2501.000000
# mean           0.062396       0.029751       0.495802
# std            2.148036       2.576632       0.500082
# min          -20.314995     -25.309275       0.000000
# 25%           -0.544998      -0.178776       0.000000
# 50%            0.052498      -0.000450       0.000000
# 75%            0.739998       0.169546       1.000000
# max           18.793991      29.698221       1.000000
#
# [8 rows x 24 columns]

# %%
bars_df["Action"] = np.where(
    bars_df["Next Close"] > bars_df["Close"], 1, -1
)

# %%
display(bars_df.head())
display(bars_df.tail())
# Out:
#                          Date       Open       High        Low      Close  \
# 11  2014-03-18 00:00:00-04:00  18.865999  18.950001  18.750000  18.938499
# 12  2014-03-19 00:00:00-04:00  18.938499  18.950001  18.471001  18.661501
# 13  2014-03-20 00:00:00-04:00  18.532000  18.650000  18.311001  18.448500
# 14  2014-03-21 00:00:00-04:00  18.549999  18.642000  17.920000  18.031000
# 15  2014-03-24 00:00:00-04:00  18.004499  18.075001  17.430000  17.592501
#
#        Volume  Dividends  Stock Splits  Next Close  Next High  ...  Open - 12  \
# 11   49670000        0.0           0.0   18.661501  18.950001  ...  17.937000
# 12   52934000        0.0           0.0   18.448500  18.650000  ...  18.195000
# 13   51170000        0.0           0.0   18.031000  18.642000  ...  18.206499
# 14  108282000        0.0           0.0   17.592501  18.075001  ...  18.702499
# 15   97470000        0.0           0.0   17.735500  17.948500  ...  18.729000
#
#     Predicted High  Predicted Low  Predicted Close  High/Low Success  \
# 11       19.008110      19.073170        19.034744                 0
# 12       18.921737      18.938262        18.922481                 0
# 13       18.623439      18.629348        18.634537                 0
# 14       18.439341      18.100165        18.278244                 0
# 15       17.928969      17.607864        17.786696                 1
#
#     Predicted Close Delta  Next Close Delta  Close Product  Close Success  \
# 11               0.096244         -0.276999      -0.026659              0
# 12               0.260980         -0.213001      -0.055589              0
# 13               0.186038         -0.417500      -0.077671              0
# 14               0.247244         -0.438499      -0.108416              0
# 15               0.194195          0.143000       0.027770              1
#
#     Action
# 11      -1
# 12      -1
# 13      -1
# 14      -1
# 15       1
#
# [5 rows x 26 columns]
#                            Date        Open        High         Low  \
# 2507  2024-02-15 00:00:00-05:00  170.580002  171.169998  167.589996
# 2508  2024-02-16 00:00:00-05:00  168.740005  170.419998  167.169998
# 2509  2024-02-20 00:00:00-05:00  167.830002  168.710007  165.740005
# 2510  2024-02-21 00:00:00-05:00  168.940002  170.229996  167.139999
# 2511  2024-02-22 00:00:00-05:00  173.100006  174.800003  171.770004
#
#            Close    Volume  Dividends  Stock Splits  Next Close   Next High  \
# 2507  169.800003  49855200        0.0           0.0  169.509995  170.419998
# 2508  169.509995  48074600        0.0           0.0  167.080002  168.710007
# 2509  167.080002  41980300        0.0           0.0  168.589996  170.229996
# 2510  168.589996  44575600        0.0           0.0  174.580002  174.800003
# 2511  174.580002  55392400        0.0           0.0  174.990005  175.750000
#
#       ...   Open - 12  Predicted High  Predicted Low  Predicted Close  \
# 2507  ...  157.000000      171.791441     168.015597       169.857266
# 2508  ...  155.869995      170.771779     167.091065       169.024534
# 2509  ...  169.190002      169.020139     165.201500       167.241072
# 2510  ...  170.199997      170.548265     166.881521       168.760008
# 2511  ...  169.389999      175.852239     171.895185       173.640420
#
#       High/Low Success  Predicted Close Delta  Next Close Delta  \
# 2507                 1               0.057262         -0.290009
# 2508                 0              -0.485460         -2.429993
# 2509                 1               0.161071          1.509995
# 2510                 0               0.170012          5.990005
# 2511                 1              -0.939581          0.410004
#
#       Close Product  Close Success  Action
# 2507      -0.016607              0      -1
# 2508       1.179665              1      -1
# 2509       0.243216              1       1
# 2510       1.018370              1       1
# 2511      -0.385232              0       1
#
# [5 rows x 26 columns]

# %%
current_position = 0
starting_cash = 1000
current_cash = starting_cash
max_position = 50
for index, row in bars_df.iterrows():
   
    close = row["Close"]
    action = row["Action"]

    if action > 0:
        if action + current_position <= max_position and action * close < current_cash:
            current_position += action
            current_cash -= action*close
        else:
            action = 0
    elif action < 0:
        if action + current_position >= 0:
            current_position += action
            current_cash += -action*close
        else:
            action = 0

    
    bars_df.loc[index, "Position"] = current_position
    bars_df.loc[index, "Cash"] = current_cash

# %%
bars_df["Holdings"] = bars_df["Close"] * bars_df["Position"]

# profit
bars_df["Strategy Value"] = bars_df["Holdings"] + bars_df["Cash"]
starting_close = bars_df.iloc[0]["Close"] 
display(f"starting_close {starting_close}")
starting_shares = math.floor(starting_cash / starting_close)
display(f"starting_shares {starting_shares}")
bars_df["Stock Value"] =  bars_df["Close"] * starting_shares

# returns
bars_df["Stock Returns"] = bars_df["Close"].pct_change()
bars_df["Strategy Returns"] = bars_df["Strategy Value"].pct_change()

# cumulative daily returns
bars_df["Stock Cumulative Returns"] = (bars_df["Stock Returns"] + 1).cumprod()
bars_df["Strategy Cumulative Returns"] = (bars_df["Strategy Returns"] + 1).cumprod()
# Out:
# 'starting_close 18.938499450683597'
# 'starting_shares 52'

# %%
bars_df.tail()
# Out:
#                            Date        Open        High         Low  \
# 2507  2024-02-15 00:00:00-05:00  170.580002  171.169998  167.589996
# 2508  2024-02-16 00:00:00-05:00  168.740005  170.419998  167.169998
# 2509  2024-02-20 00:00:00-05:00  167.830002  168.710007  165.740005
# 2510  2024-02-21 00:00:00-05:00  168.940002  170.229996  167.139999
# 2511  2024-02-22 00:00:00-05:00  173.100006  174.800003  171.770004
#
#            Close    Volume  Dividends  Stock Splits  Next Close   Next High  \
# 2507  169.800003  49855200        0.0           0.0  169.509995  170.419998
# 2508  169.509995  48074600        0.0           0.0  167.080002  168.710007
# 2509  167.080002  41980300        0.0           0.0  168.589996  170.229996
# 2510  168.589996  44575600        0.0           0.0  174.580002  174.800003
# 2511  174.580002  55392400        0.0           0.0  174.990005  175.750000
#
#       ...  Action  Position         Cash     Holdings  Strategy Value  \
# 2507  ...      -1      46.0  1949.792306  7810.800140     9760.592446
# 2508  ...      -1      45.0  2119.302300  7627.949753     9747.252053
# 2509  ...       1      46.0  1952.222299  7685.680084     9637.902383
# 2510  ...       1      47.0  1783.632302  7923.729828     9707.362130
# 2511  ...       1      48.0  1609.052300  8379.840088     9988.892388
#
#       Stock Value  Stock Returns  Strategy Returns  Stock Cumulative Returns  \
# 2507  8829.600159      -0.006901         -0.005650                  8.965864
# 2508  8814.519714      -0.001708         -0.001367                  8.950550
# 2509  8688.160095      -0.014335         -0.011219                  8.822241
# 2510  8766.679810       0.009038          0.007207                  8.901972
# 2511  9078.160095       0.035530          0.029002                  9.218259
#
#       Strategy Cumulative Returns
# 2507                     9.760592
# 2508                     9.747252
# 2509                     9.637902
# 2510                     9.707362
# 2511                     9.988892
#
# [5 rows x 35 columns]

# %%
stock_cumulative_returns = bars_df.hvplot.line(
    x="Date",
    y="Stock Cumulative Returns",
)

# %%
strategy_cumulative_returns = bars_df.hvplot.line(
    x="Date",
    y="Strategy Cumulative Returns",
)

# %%
stock_cumulative_returns * strategy_cumulative_returns
# Out:
# :Overlay
#    .Curve.I  :Curve   [Date]   (Stock Cumulative Returns)
#    .Curve.II :Curve   [Date]   (Strategy Cumulative Returns)

# %%
cash = bars_df.hvplot.line(
    x="Date",
    y="Cash",
)

# %%
holdings = bars_df.hvplot.line(
    x="Date",
    y="Holdings",
)

# %%
cash*holdings
# Out:
# :Overlay
#    .Curve.I  :Curve   [Date]   (Cash)
#    .Curve.II :Curve   [Date]   (Holdings)

# %%
position = bars_df.hvplot.line(
    x="Date",
    y="Position",
)
position
# Out:
# :Curve   [Date]   (Position)
